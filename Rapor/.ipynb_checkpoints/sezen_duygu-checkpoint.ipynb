# %%
from transformers import BertTokenizer, TFBertForSequenceClassification
import tensorflow as tf

# Dosyadan metinleri okuma
file_path = "duygucumleleri.txt"
with open(file_path, "r", encoding="utf-8") as file:
    texts = file.readlines()

# Önceden eğitilmiş BERT modelini ve tokenizer'ını yükleyelim
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = TFBertForSequenceClassification.from_pretrained(model_name)

# Metinleri BERT modeline uygun hale getirme
input_ids = tokenizer(texts, return_tensors="tf", padding=True, truncation=True)["input_ids"]

# Metinleri modelde değerlendirme
outputs = model(input_ids)
predictions = tf.nn.softmax(outputs.logits, axis=-1)

# Sentiment etiketlerini ve güven skorlarını yazdırma
for text, prediction in zip(texts, predictions):
    label = tf.argmax(prediction).numpy()
    confidence = prediction[label].numpy()
    print(f"Text: {text.strip()}\nSentiment: {label}, Confidence: {confidence}\n")
# Out:
# WARNING:tensorflow:From C:\Users\batur\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at nlptown/bert-base-multilingual-uncased-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.
# Text: 1 think met beach northern shores sydney round world travels
# Sentiment: 4, Confidence: 0.43074658513069153
#
# Text: 2 fair say isnt wwe bcuz travel etc
# Sentiment: 0, Confidence: 0.3425643742084503
#
# Text: 3 restrictions international travel someone indicted
# Sentiment: 0, Confidence: 0.4745014011859894
#
# Text: 4 content creators love
# Sentiment: 4, Confidence: 0.41524896025657654
#
# Text: 5 space travel one things everyone exited regardless political views
# Sentiment: 0, Confidence: 0.6112346053123474
#
# Text: 6 hope bought travel insurance
# Sentiment: 0, Confidence: 0.3754490315914154
#
# Text: 7 youre baseball stadium ball park hot dog trumps strictly speaking stadiums chicken tenders fries combo elite
# Sentiment: 4, Confidence: 0.5071924924850464
#
# Text: 8 sound empty
# Sentiment: 0, Confidence: 0.42089536786079407
#
# Text: 9 want get experience things see adventure
# Sentiment: 4, Confidence: 0.403481662273407
#
# Text: 10 book star vegas trip
# Sentiment: 4, Confidence: 0.595982551574707
#
# Text: 11 theyre tire company
# Sentiment: 4, Confidence: 0.2371903359889984
#
# Text: 12 start business december tshirt supply tshirt printing
# Sentiment: 4, Confidence: 0.2828134298324585
#
# Text: 13 far open air prison lift blinders google
# Sentiment: 4, Confidence: 0.2406793087720871
#
# Text: 14 new pair tracks
# Sentiment: 3, Confidence: 0.2749532163143158
#
# Text: 15 ever waiting international flight back us air e one shut whole international airport
# Sentiment: 0, Confidence: 0.7157495617866516
#
# Text: 16 best collection offer weth
# Sentiment: 4, Confidence: 0.700891375541687
#
# Text: 17 may actually kill ppl
# Sentiment: 0, Confidence: 0.752069890499115
#
# Text: 18 wife every show stpaul played million pieces wedding isle skye scotland
# Sentiment: 4, Confidence: 0.4420723617076874
#
# Text: 19 wonders would see
# Sentiment: 3, Confidence: 0.24885599315166473
#
# Text: 20 ends tue th sep pm
# Sentiment: 0, Confidence: 0.5728844404220581
#
# Text: 21 best advice ever received grief counselor year period significant losses one doesnt journey grief one travels grief
# Sentiment: 0, Confidence: 0.5497466921806335
#
# Text: 22 ohayo hong kong
# Sentiment: 0, Confidence: 0.32074812054634094
#
# Text: 23 wrapped bodies today
# Sentiment: 0, Confidence: 0.25958335399627686
#
# Text: 24 striker sustained calf injury stay argentina recover
# Sentiment: 0, Confidence: 0.5675508975982666
#
# Text: 25 tourist travel warning traveling country fewer freedoms
# Sentiment: 0, Confidence: 0.31847745180130005
#
# Text: 26 discover premium highquality travel products
# Sentiment: 4, Confidence: 0.4145466983318329
#
# Text: 27 na nite
# Sentiment: 0, Confidence: 0.28638893365859985
#
# Text: 28 travel min away
# Sentiment: 2, Confidence: 0.25199469923973083
#
# Text: 29 cant read youre thick unreal
# Sentiment: 0, Confidence: 0.523256242275238
#
# Text: 30 exciting news travel enthusiasts new product launch magfast tues sept th
# Sentiment: 0, Confidence: 0.4640420973300934
#
# Text: 31 love international travel
# Sentiment: 3, Confidence: 0.2684434950351715
#
# Text: 32 vaccines required certain countries
# Sentiment: 0, Confidence: 0.2524986267089844
#
# Text: 33 travel rift help needed
# Sentiment: 3, Confidence: 0.33396923542022705
#
# Text: 34 expenses like cocktails tattoos doordash streaming smartphones travel dining etc probably dont help either
# Sentiment: 0, Confidence: 0.3473320007324219
#
# Text: 35 let pick moderator
# Sentiment: 3, Confidence: 0.24576343595981598
#
# Text: 36 found great deal lazada
# Sentiment: 4, Confidence: 0.22941558063030243
#
# Text: 37 yes make pm uk travel horse cart
# Sentiment: 4, Confidence: 0.24770499765872955
#
# Text: 38 whos ready travel
# Sentiment: 3, Confidence: 0.25233644247055054
#
# Text: 39 jingle bells travels sells wouldnt want trip
# Sentiment: 0, Confidence: 0.30785423517227173
#
# Text: 40 think theyre absolutely horrible
# Sentiment: 0, Confidence: 0.8654890656471252
#
# Text: 41 always remember travelling across egypt late travel guide speaking nations cycles egyptian genuinely believed china would next superpower
# Sentiment: 4, Confidence: 0.2725813090801239
#
# Text: 42 problem spread last century muslim world well
# Sentiment: 2, Confidence: 0.22384585440158844
#
# Text: 43 right kind story keeps night makes terrified travel exist public
# Sentiment: 4, Confidence: 0.4880411922931671
#
# Text: 44 say need permission go places
# Sentiment: 0, Confidence: 0.3448657989501953
#
# Text: 45 believe merit
# Sentiment: 4, Confidence: 0.28814125061035156
#
# Text: 46 wanna travel future see grave like jk
# Sentiment: 0, Confidence: 0.2858385443687439
#
# Text: 47 uhuru kenyan goodwill petition relevant authorities answers compensation privacy data protection laws
# Sentiment: 0, Confidence: 0.5547666549682617
#
# Text: 48 railwayseva drmdnr ecrlyhjp rpfdnr
# Sentiment: 0, Confidence: 0.2994382381439209
#
# Text: 49 todays recommendation fat sugar
# Sentiment: 0, Confidence: 0.24593786895275116
#
# Text: 50 dont like shes holding ball double team risking jump ball travel multiple times
# Sentiment: 0, Confidence: 0.40220731496810913
